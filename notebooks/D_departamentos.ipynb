# %% [markdown]
# <a href="https://colab.research.google.com/github/MarioV3232/etl-data-pipeline2507452022/blob/main/notebooks/D_departamentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

url="https://raw.githubusercontent.com/MarioV3232/etl-data-pipeline2507452022/refs/heads/main/data/raw/D_departamentos.csv"
df = pd.read_csv(url)

df.head()
# Out:
#   id_departamento departamento   ubicacion
# 0             D10          TI   Edificio A
# 1             D11     Finanzas      Remoto
# 2             D12         RRHH  Edificio A
# 3             D13       Ventas  Edificio A
# 4             D14      Compras  Edificio A

# %%
#Exploracion

df.shape
df.columns
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_departamento  9 non-null      object
#  1   departamento     9 non-null      object
#  2   ubicacion        9 non-null      object
# dtypes: object(3)
# memory usage: 348.0+ bytes
# id_departamento    0
# departamento       0
# ubicacion          0
# dtype: int64

# %%
# Limpiar Datos
df = df.drop_duplicates()
df = df.dropna()

# %%
# Separar curated y rejects
df_rejects = df[df.isnull().any(axis=1)]
df_curated = df.dropna()
print(f"Curated: {len(df_curated)} | Rejects: {len(df_rejects)}")
# Out:
# Curated: 8 | Rejects: 0

# %%
# Cargar a PostgreSQL
from sqlalchemy import create_engine

engine = create_engine("postgresql://etl_seguros_30a9_user:Y6BGlJaThP4Pm8wnb3BmpmJ4AACL8Cuq@dpg-d6qu6u5m5p6s73ea8r60-a.oregon-postgres.render.com/etl_seguros_30a9")
df_curated.to_sql("departamento_curated", engine, if_exists="replace", index=False)
df_rejects.to_sql("departamento_rejects", engine, if_exists="replace", index=False)
print("Departamento cargado")
# Out:
# Departamento cargado

# %%
# Guardar curated y rejects localmente en Colab
df_curated.to_csv("departamento_curated.csv", index=False)
df_rejects.to_csv("departamento_rejects.csv", index=False)
